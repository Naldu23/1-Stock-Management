# %% [markdown]
# <a href="https://colab.research.google.com/github/Naldu23/1-Stock-Management/blob/main/stock_info_kor.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install opendartreader

# %%
import OpenDartReader

api_key = 'fe295f0b53d3a804151ba50599135d0a877396d0'
dart = OpenDartReader(api_key)

dart.list('삼성전자', start='2024-09-10', end='2024-12-09')
# Out:
#     corp_code corp_name stock_code corp_cls            report_nm  \
# 0    00126380      삼성전자     005930        Y  임원ㆍ주요주주특정증권등소유상황보고서
# 1    00126380      삼성전자     005930        Y  임원ㆍ주요주주특정증권등소유상황보고서
# 2    00126380      삼성전자     005930        Y  임원ㆍ주요주주특정증권등소유상황보고서
# 3    00126380      삼성전자     005930        Y  임원ㆍ주요주주특정증권등소유상황보고서
# 4    00126380      삼성전자     005930        Y  임원ㆍ주요주주특정증권등소유상황보고서
# ..        ...       ...        ...      ...                  ...
# 120  00126380      삼성전자     005930        Y  임원ㆍ주요주주특정증권등소유상황보고서
# 121  00126380      삼성전자     005930        Y  임원ㆍ주요주주특정증권등소유상황보고서
# 122  00126380      삼성전자     005930        Y  임원ㆍ주요주주특정증권등소유상황보고서
# 123  00126380      삼성전자     005930        Y  임원ㆍ주요주주특정증권등소유상황보고서
# 124  00126380      삼성전자     005930        Y  임원ㆍ주요주주특정증권등소유상황보고서
#
#            rcept_no flr_nm  rcept_dt rm
# 0    20241209000359    박상훈  20241209
# 1    20241209000001    이석림  20241209
# 2    20241206000555    박승일  20241206
# ...

# %%
dart.report('삼성전자', '배당', 2023)
# Out:
#           rcept_no corp_cls corp_code corp_name              se      thstrm  \
# 0   20240312000736        Y  00126380      삼성전자       주당액면가액(원)         100
# 1   20240312000736        Y  00126380      삼성전자  (연결)당기순이익(백만원)  14,473,401
# 2   20240312000736        Y  00126380      삼성전자  (별도)당기순이익(백만원)  25,397,099
# 3   20240312000736        Y  00126380      삼성전자    (연결)주당순이익(원)       2,131
# 4   20240312000736        Y  00126380      삼성전자    현금배당금총액(백만원)   9,809,438
# 5   20240312000736        Y  00126380      삼성전자    주식배당금총액(백만원)           -
# 6   20240312000736        Y  00126380      삼성전자   (연결)현금배당성향(%)       67.80
# 7   20240312000736        Y  00126380      삼성전자      현금배당수익률(%)        1.90
# 8   20240312000736        Y  00126380      삼성전자      현금배당수익률(%)        2.40
# 9   20240312000736        Y  00126380      삼성전자      주식배당수익률(%)           -
# 10  20240312000736        Y  00126380      삼성전자      주식배당수익률(%)           -
# ...

# %%
df = dart.finstate_all('005930', 2021)
print('row count', len(df))
df.head()
# Out:
# reprt_code='11011', fs_div='CFS' (사업보고서, 연결제무제표)'
# row count 186
#          rcept_no reprt_code bsns_year corp_code sj_div  sj_nm  \
# 0  20220308000798      11011      2021  00126380     BS  재무상태표
# 1  20220308000798      11011      2021  00126380     BS  재무상태표
# 2  20220308000798      11011      2021  00126380     BS  재무상태표
# 3  20220308000798      11011      2021  00126380     BS  재무상태표
# 4  20220308000798      11011      2021  00126380     BS  재무상태표
#
#                                           account_id       account_nm  \
# 0                            ifrs-full_CurrentAssets             유동자산
# 1                   ifrs-full_CashAndCashEquivalents         현금및현금성자산
# 2  dart_ShortTermDepositsNotClassifiedAsCashEquiv...           단기금융상품
# 3                                       -표준계정코드 미사용-      단기상각후원가금융자산
# 4  ifrs-full_CurrentFinancialAssetsAtFairValueThr...  단기당기손익-공정가치금융자산
#
#   account_detail thstrm_nm    thstrm_amount frmtrm_nm    frmtrm_amount  \
# ...

# %%
# 삼성전자 2021 재무제표

df = dart.finstate('삼성전자', 2021) # 사업보고서

print('row count', len(df))
df.head()
# Out:
# row count 28
#          rcept_no reprt_code bsns_year corp_code stock_code fs_div   fs_nm  \
# 0  20220308000798      11011      2021  00126380     005930    CFS  연결재무제표
# 1  20220308000798      11011      2021  00126380     005930    CFS  연결재무제표
# 2  20220308000798      11011      2021  00126380     005930    CFS  연결재무제표
# 3  20220308000798      11011      2021  00126380     005930    CFS  연결재무제표
# 4  20220308000798      11011      2021  00126380     005930    CFS  연결재무제표
#
#   sj_div  sj_nm account_nm  ...      thstrm_dt        thstrm_amount frmtrm_nm  \
# 0     BS  재무상태표       유동자산  ...  2021.12.31 현재  218,163,185,000,000    제 52 기
# 1     BS  재무상태표      비유동자산  ...  2021.12.31 현재  208,457,973,000,000    제 52 기
# 2     BS  재무상태표       자산총계  ...  2021.12.31 현재  426,621,158,000,000    제 52 기
# 3     BS  재무상태표       유동부채  ...  2021.12.31 현재   88,117,133,000,000    제 52 기
# 4     BS  재무상태표      비유동부채  ...  2021.12.31 현재   33,604,094,000,000    제 52 기
#
# ...

# %%
df
# Out:
#           rcept_no reprt_code bsns_year corp_code stock_code fs_div   fs_nm  \
# 0   20220308000798      11011      2021  00126380     005930    CFS  연결재무제표
# 1   20220308000798      11011      2021  00126380     005930    CFS  연결재무제표
# 2   20220308000798      11011      2021  00126380     005930    CFS  연결재무제표
# 3   20220308000798      11011      2021  00126380     005930    CFS  연결재무제표
# 4   20220308000798      11011      2021  00126380     005930    CFS  연결재무제표
# 5   20220308000798      11011      2021  00126380     005930    CFS  연결재무제표
# 6   20220308000798      11011      2021  00126380     005930    CFS  연결재무제표
# 7   20220308000798      11011      2021  00126380     005930    CFS  연결재무제표
# 8   20220308000798      11011      2021  00126380     005930    CFS  연결재무제표
# 9   20220308000798      11011      2021  00126380     005930    CFS  연결재무제표
# 10  20220308000798      11011      2021  00126380     005930    CFS  연결재무제표
# ...

# %%
# 삼성전자 2021Q1 재무제표

df = dart.finstate('삼성전자', 2021, reprt_code='11013') # 2018년 1분기 보고서 재무제표

print('row count', len(df))
df.head()
# Out:
# row count 28
#          rcept_no reprt_code bsns_year corp_code stock_code fs_div   fs_nm  \
# 0  20210517001185      11013      2021  00126380     005930    CFS  연결재무제표
# 1  20210517001185      11013      2021  00126380     005930    CFS  연결재무제표
# 2  20210517001185      11013      2021  00126380     005930    CFS  연결재무제표
# 3  20210517001185      11013      2021  00126380     005930    CFS  연결재무제표
# 4  20210517001185      11013      2021  00126380     005930    CFS  연결재무제표
#
#   sj_div  sj_nm account_nm   thstrm_nm      thstrm_dt        thstrm_amount  \
# 0     BS  재무상태표       유동자산  제 53 기1분기말  2021.03.31 현재  209,155,353,000,000
# 1     BS  재무상태표      비유동자산  제 53 기1분기말  2021.03.31 현재  183,670,921,000,000
# 2     BS  재무상태표       자산총계  제 53 기1분기말  2021.03.31 현재  392,826,274,000,000
# 3     BS  재무상태표       유동부채  제 53 기1분기말  2021.03.31 현재   90,109,462,000,000
# 4     BS  재무상태표      비유동부채  제 53 기1분기말  2021.03.31 현재   28,448,221,000,000
#
# ...

# %%
files = dart.attach_files(rcp_no)
for title, url in files.items():
    print(title)
    print(url)
    dart.download(url, title)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-10-5c3e89ed2b08> in <cell line: 1>()
# ----> 1 files = dart.attach_files(rcp_no)
#       2 for title, url in files.items():
#       3     print(title)
#       4     print(url)
#       5     dart.download(url, title)
#
# NameError: name 'rcp_no' is not defined
